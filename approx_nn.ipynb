# %% [markdown]
# # <CENTER> Approximate nearest neighbors</CENTER>

# %% [markdown]
# ## Assignment (in French) by Guillaume Pitel

# %% [markdown]
# À partir des exemples donnés ici :
# https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html
#
# 1°) Faire une Latent Semantic Analysis de 20newsgroups. (TuncatedSVD avec
# l’algo Randomized en 128 dimensions à partir de la matrice TF-IDF)
#
# 2°) Tirer aléatoirement 1 document de chaque newsgroup et calculer ses 8
# plus proches voisins selon la distance cosinus (normaliser les vecteurs
# représentant les documents) => il faut sortir les subjects des news et leur
# newsgroup d’origine.
#
# 3°) Développer une Product Quantization, réduire tous les représentants de
# document (utiliser l’algorithme K-Means de sklearn) avec les paramètres
# suivants : K=256, faire les K-means sur des tranches de 8 dimensions (on aura
# donc 16 sous-clusterings de 256).
#
# 4°) Calculer les voisins des mêmes documents avec la version PQ (calcul direct à
# partir des distances inter-clusters, et non pas en recréant des vecteurs
# complets).

# %% [markdown]
# ## 1. Preparation

# %% [markdown]
# **Disclaimer** <BR>
# We factorized our code as much as we could. Therefore, our answers require a long preparation, as this material is used without or with little modifications for all questions. In other words, some attributes, functions or methods written here might actually concern later questions only.<BR>
# Nevertheless, once the preparation is complete, answering to all questions is very quick.

# %% [markdown]
# ### 1.1. Imports

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import fetch_20newsgroups
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %% [markdown]
# ### 1.2. Constants

# %%
# Number of clusters for K-Means performed in Q3 (called K in the assignment)
N_CLUSTERS = 256 

# Output dimension for the SVD performed in Q1
N_COMPONENTS = 128 

# Number of subclusterings made during Product Quantization (PQ), see Q3 & Q4
N_SUBCLUSTERINGS = 16 

# Number of different topics in 20Newsgroups
N_TOPICS = 20 

# Dimension of a subvector in PQ
PQ_DIM = 8 

# Seed for sklearn algorithms using a random state
RANDOM_STATE = 42

# %% [markdown]
# ### 1.3. A class handling the 20Newsgroups dataset

# %% [markdown]
# #### 1.3.1. Definition

# %% [markdown]
# Let's build a handy class that performs most of the operations we want on the 20Newsgroups dataset.

# %%
class My20Newsgroups:
  '''
  This class performs various operations on the 20Newsgroups dataset.
 
  Attributes:
  * self.train: the training part of the 20Newsgroups dataset,
  which consists in 11314 documents.
  * self.data: alias for self.train.data
  * self.tf_idf: TF-IDF matrix for the dataset.
  * self.svd: LSA (aka truncated SVD) on the TF-IDF matrix (see Q1).
  * self.n_components: output dimension for the SVD.
  Passed in as the only argument to the constructor.
  * self.sample: a random sample of 20 documents, one for each topic
  (see Q2). Stored as the tuple of the indexes of these 20 documents.
  '''

  def __init__(self, n_components=N_COMPONENTS):
    '''
    Constructor.
    '''
    # Import the dataset
    self.train = fetch_20newsgroups(data_home=None, 
                                    shuffle=True, 
                                    subset='train', 
                                    random_state=RANDOM_STATE, 
                                    download_if_missing=True)
    self.data = self.train.data

    # Get the TF-IDF matrix
    train_counts = CountVectorizer().fit_transform(self.data)
    self.tf_idf = TfidfTransformer().fit_transform(train_counts)              
    
    # Perform a LSA (aka truncated SVD) on it
    self.n_components = n_components
    self.svd = TruncatedSVD(self.n_components).fit_transform(self.tf_idf)

    # Sampling - explanations about the code:
    # c represents a topic.
    # For a given c, np.where(self.train.target == c)[0] is the list of all
    # indexes of documents in the dataset having topic c.
    # np.random.choice() picks at random an index in this list.
    self.sample = tuple(np.random.choice(np.where(self.train.target == c)[0]) \
                   for c in range(N_TOPICS))
           
  def subject(self, i):
    '''
    Get the line "Subject:" (second line) for the i-th document.
    The word "Subject:" itself is removed.
    '''
    return self.data[i].split('\n')[1][len('Subject: ') :]
      
  def topic(self, i):
    '''
    Get the topic (=label, or class, or newsgroup) for the i-th document.
    Return it as a string, e.g. 'comp.sys.mac.hardware'.
    '''
    return self.train.target_names[self.train.target[i]]

  def its(self, i):
    '''
    Return the triple (i, topic, subject) for the i-th document.
    '''
    return (i, self.topic(i), self.subject(i))

# %% [markdown]
# #### 1.3.2. Instantiation

# %% [markdown]
# This takes a little time, because the LSA is performed at this stage.

# %%
dataset = My20Newsgroups()

# %% [markdown]
# #### 1.3.3. A few tests

# %%
# Number of documents
len(dataset.data)
# Out:
# 11314

# %%
# Print the 42nd document
i = 42
for line in dataset.data[i].split('\n'):
  print(line)
# Out:
# From: ab245@cleveland.Freenet.Edu (Sam Latonia)
# Subject: Re: Need phone number for Western Digital (ESDI problem)
# Organization: Case Western Reserve University, Cleveland, Ohio (USA)
# Lines: 5
# NNTP-Posting-Host: slc10.ins.cwru.edu
#
#
# Western Digital 1-800-832-4778.....Sam
# --
# Gosh..I think I just installed a virus..It was called MS DOS6...
# Don't copy that floppy..BURN IT...I just love Windows...CRASH...

# %%
# Subject of the 42nd document
dataset.subject(i)
# Out:
# 'Re: Need phone number for Western Digital (ESDI problem)'

# %%
# Topic (=class, returned as a string) of the 42nd document
dataset.topic(i)
# Out:
# 'comp.sys.ibm.pc.hardware'

# %% [markdown]
# ### 1.4. A class searching nearest neighbors in any dataset

# %% [markdown]
# #### 1.4.1. Definition

# %% [markdown]
# Let's build a class that takes a dataset passed in as the only argument to the constructor, and searches the nearest neighbors of a given element according to various metrics: the cosine distance for Q2, or the distance given by PQ for Q3 and Q4.

# %%
class NearestNeighborsFinder:
  '''  
  This class computes the nearest neighbors of a given element in
  a given dataset, w.r.t. various metrics.
  
  Attributes:
  * self.X: the data matrix, passed in as the only argument
  to the constructor.
  Vectors corresponding to the elements of the dataset must be
  stored as rows, and features as columns. If you followed the other
  convention, consider transposing X first.
  * self.norms: 1-D NumPy array of the Euclidean norms of the rows of X.
  * (self.PQ_labels, self.PQ_centroid_distances): result of PQ(),
  see the docstring of this method below. Used for Q3 and Q4.
  ''' 

  # For Q3 and Q4
  def PQ(self):
    '''
    Perform a PQ on the dataset, with parameters (constants) defined in §1.2.
    Return a pair (PQ_labels, PQ_centroid_distances) defined as follows.
    * 'PQ_labels' is a matrix of shape (n, r), where
    n = self.X.shape[0] and r = N_SUBCLUSTERINGS.
    Each row of 'PQ_labels' is the 1-D array of labels through PQ for the
    corresponding row of the dataset; in other words, PQ_labels[i,:] is
    the compression of self.X[i,:] through PQ.
    * 'PQ_centroid_distances' is a 3-D array of shape (r, k, k) with
    k = N_CLUSTERS. For the j-th K-Means performed during PQ,
    PQ_centroid_distances[j, :, :] is the matrix of the
    *squared* L2-distances between all centroids.
    '''
    # Shorter names for dims
    d, k, n, r = PQ_DIM, N_CLUSTERS, self.X.shape[0], N_SUBCLUSTERINGS 

    # Sanity check
    assert N_COMPONENTS == d * r, \
      "Incompatible values: N_COMPONENTS != PQ_DIM * N_SUBCLUSTERINGS"

    # Initialization 
    PQ_centroid_distances = np.zeros(shape=(r, k, k))
    PQ_labels = np.zeros(shape=(n, r), dtype=np.uint8)

    # Main loop
    for j in range(r):
      # Extract the matrix of subvectors
      sub_X = self.X[ : , j*d : (j+1)*d]
  
      # Train a KMeans on it
      kmeans = KMeans(n_clusters=k,
                      n_init=5,
                      max_iter=5,
                      random_state=RANDOM_STATE,
                      n_jobs=-1,
                      algorithm='elkan'
                     ).fit(sub_X)
  
      # Fill the labels accordingly
      PQ_labels[:, j] = kmeans.labels_

      # We compute the squared L2-distances between the centroids c_i as follows.
      # We have ||c_i-c_i'||**2 = G[i,i'] + G[i',i'] - 2*G[i,i'],
      # where G is the Gram matrix of the centroids. If the centroids are
      # stored as rows in a matrix C, then we easily have G = C @ C.T.
      # Let D denote the 1-D array equal to the diagonal part of G.
      # Then, the square matrix of the G[i',i'] (i' being a column index)
      # is N = np.tile(D, (k, 1)), and the square matrix of the G[i,i]
      # (i being a row index) is N.T. Therefore, we have
      # (*): ||c_i-c_i'||**2 = (N.T)[i,i'] + N[i,i'] - 2*G[i,i'],
      # whence the following code.
      C = kmeans.cluster_centers_ # matrix of centroids
      G = C @ C.T # Gram matrix of centroids
      D = np.diag(G) # this is a 1-D array
      N = np.tile(D, (k,1)) # all rows of N equal D
      PQ_centroid_distances[j, :, :] = N.T + N - 2 * G # code for (*)

    return PQ_labels, PQ_centroid_distances
  
  # For Q2, Q3 and Q4
  def __init__(self, X):
    '''
    Constructor. 
    Compute the norms of the rows of X and performs PQ on the whole dataset.
    '''
    self.X = X
    self.norms = np.linalg.norm(self.X, axis=-1)
    self.PQ_labels, self.PQ_centroid_distances = self.PQ()

  # For Q2
  def cosine_distances(self, i):
    '''
    Return a 1-D array storing a refinement of the cosine distances
    between the i-th row of self.X and all the other rows.
    It is a refinement in the sense that it is not the actual
    cosine distance, but an increasing function of it which is
    simpler to compute. This changes nothing as far as nearest
    neighbor search is concerned.
    '''
    dot_products = self.X @ self.X[i,:].T
    # Refinement: for the true cosine distance, we must actually
    # return
    #
    # 1 - dot_products / (self.norms * N)
    #
    # with N = np.linalg.norm(self.X[i,:]).
    # But as far as nearest neighbor search from X[i,:] is concerned,
    # there is no need to divide by N which is constant, nor to add 1,
    # so we may return the following:
    return - dot_products / self.norms
  
  # For Q4
  def PQ_distances(self, i):
    '''
    Return the 1-D array of the squared L2-distances between
    the i-th row of self.X and all the other rows, on which PQ
    has already been applied.
    '''
    n = self.X.shape[0]
    out = np.zeros(n)
    for h in range(n): # index for rows of X
      for j in range(N_SUBCLUSTERINGS): # index for subvectors, or K-Means
        label_h = self.PQ_labels[h, j]
        label_i = self.PQ_labels[i, j]  
        out[h] += self.PQ_centroid_distances[j, label_h, label_i] 
    return out
    
  # For Q2 and Q4
  def nearest_neighbors(self, n_neighbors, dist):
    '''
    Return, as a (n_neighbors+1)-tuple, the *indexes* of a given element
    x in the dataset and of its n_neighbors nearest neighbors.
    The index of x is returned first, then the one of its nearest
    neighbor, then the one of its second nearest neighbor, and so on.
    The neighbors are computed w.r.t. the 'dist' parameter,
    which must be a 1-D array containing the true distances,
    or *an increasing function of the distances*, between x and
    all elements in the dataset.
    '''
    return tuple(sorted
                 (range(self.X.shape[0]), key=lambda j: dist[j])
                 [: n_neighbors + 1])

# %% [markdown]
# #### 1.4.2. Instantiation

# %% [markdown]
# This takes a while (~1 min on a fast computer), because the PQ is performed at this stage.

# %%
nnf = NearestNeighborsFinder(dataset.svd)

# %% [markdown]
# ### 1.5. A function searching nearest neighbors  in the 20Newsgroups dataset

# %% [markdown]
# While the previous 2 classes work independenty, searching nearest neighbors of a document in the 20Newsgroups dataset, like in Q2 and Q4, uses both classes through the function `nearest_neighbors()` defined below.
# Please read its docstring carefully to understand what is the format for our
# answers to Q2 and Q4. Note that in particular, we return 9-tuples instead of 8-tuples, because
# we nevertheless have to mention the current document before its 8 nearest neighbors.

# %%
def nearest_neighbors(n_neighbors, dataset, nnf, distance):
  '''
  Parameters:
  * n_neighbors: the number of neighbors we want.
  * dataset: instance of the My20Newsgroups class.
  * nnf: instance of the NearestNeighborsFinder class, typically:
  nnf = NearestNeighborsFinder(dataset.svd)
  * distance: 
  must be either the string 'cos' for the cosine distance as in Q2,
  or the string 'PQ' for the distance given by PQ as in Q4.

  Return a dictionary of (key, value) pairs, where:
  * each key is the name of a topic (there are 20 of them),
  * each value is a (1 + n_neighbors)-tuple, where:
    - the 0th component deals with the randomly chosen document corresponding
    to this topic,
    - the next component deals with its closest neighbor, w.r.t. 'distance',
    - the next component deals with the second closest neighbor,
    and so on;
    - each component is itself a triple (index, topic, subject)
    corresponding to the relevant document.
  '''
  
  if distance not in ['cos', 'PQ']:
    raise TypeError("distance must be either 'cos' or 'PQ'")    
  
  dict_ = {}
  for c in range(N_TOPICS):
    doc = dataset.sample[c]
    key = dataset.topic(doc)
    
    if distance == 'cos':
      dist = nnf.cosine_distances(doc)
    else:
      dist = nnf.PQ_distances(doc)
    
    nn_idx = nnf.nearest_neighbors(n_neighbors, dist)
    value = tuple(dataset.its(i) for i in nn_idx)
    
    dict_[key] = value
  
  return dict_

# %% [markdown]
# ## 2. Answers

# %% [markdown]
# ### 2.1. Question 1

# %% [markdown]
# **Our answer to this question is just the** `dataset.svd` **attribute.**
#
# Note that the output dimension, namely `dataset.n_components`, is already set to the default value, which is 128.
# We merely check here that the output shape is correct: it must be `(11314, 128)`, as there are 11314 documents and we keep 128 features.

# %%
dataset.svd.shape
# Out:
# (11314, 128)

# %% [markdown]
# ### 2.2. Question 2

# %% [markdown]
# #### 2.2.1. Sampling

# %% [markdown]
# In `dataset.sample`, we chose at random 1 document for each topic.
# For each of them, let's print its `.its()` (=index, topic, subject):

# %%
for i in dataset.sample:
  print(dataset.its(i))
# Out:
# (8541, 'alt.atheism', 'Re: Genocide is Caused by Theism : Evidence?')
# (6717, 'comp.graphics', 'Re: Rumours about 3DO ???')
# (2557, 'comp.os.ms-windows.misc', 'Re: Utility for updating Win.ini and system.ini')
# (6479, 'comp.sys.ibm.pc.hardware', 'ion: na')
# (3555, 'comp.sys.mac.hardware', "Re: Centris 610 Video Problem - I'm having it also!")
# (6945, 'comp.windows.x', 'Re: Animation with XPutImage()?')
# (9931, 'misc.forsale', 'Onkyo 55w/ch integrated amp forsale:')
# (6580, 'rec.autos', 'Re: New Alarm Proposal')
# (4470, 'rec.motorcycles', 'Re: Observation re: helmets')
# (10350, 'rec.sport.baseball', "I've found the secret!")
# (5713, 'rec.sport.hockey', 'My Predictions of a classic playoff year!')
# (8983, 'sci.crypt', 'Clipper chip -- technical details')
# (3758, 'sci.electronics', 'Re: Illusion')
# (1329, 'sci.med', 'Re: Migraines')
# (993, 'sci.space', 'Re: Boom!  Whoosh......')
# (5004, 'soc.religion.christian', 'Re: The arrogance of Christians')
# (8281, 'talk.politics.guns', 'S4@psuvm.psu.edu>')
# (10377, 'talk.politics.mideast', 'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES')
# (6107, 'talk.politics.misc', 'PBC@CUNYVM.BITNET>')
# (7142, 'talk.religion.misc', 'Re: A Message for you Mr. President: How do you know what happened?')

# %% [markdown]
# #### 2.2.2. Nearest neighbors

# %% [markdown]
# We just need to call `nearest_neighbors()` (see §1.5) with the parameter `distance='cos'`:

# %%
nearest_neighbors(n_neighbors=8, dataset=dataset, nnf=nnf, distance='cos')
# Out:
# {'alt.atheism': ((8541,
#    'alt.atheism',
#    'Re: Genocide is Caused by Theism : Evidence?'),
#   (8071, 'alt.atheism', 'Re: islamic genocide'),
#   (3289, 'talk.religion.misc', 'Re: Albert Sabin'),
#   (8900, 'alt.atheism', 'Re: free moral agency and Jeff Clark'),
#   (5081, 'alt.atheism', 'Re: An Anecdote about Islam'),
#   (8488, 'alt.atheism', 'Re: free moral agency and Jeff Clark'),
#   (260, 'alt.atheism', 'Re: An Anecdote about Islam'),
#   (9694, 'alt.atheism', 'Re: ISLAM: a clearer view'),
#   (1534, 'alt.atheism', 'Re: Wholly Babble (Was Re: free moral agency)')),
#  'comp.graphics': ((6717, 'comp.graphics', 'Re: Rumours about 3DO ???'),
#   (5761, 'comp.graphics', 'Re: Rumours about 3DO ???'),
#   (6142, 'comp.graphics', 'Re: Rumours about 3DO ???'),
#   (10663, 'comp.graphics', 'Re: Rumours about 3DO ???'),
#   (5328, 'comp.graphics', 'I need to make my VGA do shades.'),
#   (11205, 'comp.sys.mac.hardware', 'Re: Disappointed by La Cie'),
#   (9647, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (6311, 'comp.graphics', 'Re: VGA 640x400 graphics mode'),
#   (7772, 'comp.sys.mac.hardware', 'What is  "ROM accelerated video"?')),
#  'comp.os.ms-windows.misc': ((2557,
#    'comp.os.ms-windows.misc',
#    'Re: Utility for updating Win.ini and system.ini'),
#   (2452,
#    'comp.os.ms-windows.misc',
#    'Re: Utility for updating Win.ini and system.ini'),
#   (675,
#    'comp.os.ms-windows.misc',
#    'Utility for updating Win.ini and system.ini'),
#   (255,
#    'comp.os.ms-windows.misc',
#    'Re: Utility for updating Win.ini and system.ini'),
#   (58,
#    'comp.os.ms-windows.misc',
#    'Re: Utility for updating Win.ini and system.ini'),
#   (1057, 'comp.os.ms-windows.misc', 'phen.Gibson@sonoma.edu <Stephen Gibson>'),
#   (6499,
#    'comp.os.ms-windows.misc',
#    'Re: Utility for updating Win.ini and system.ini'),
#   (3871,
#    'comp.os.ms-windows.misc',
#    'Re: Utility for updating Win.ini and system.ini'),
#   (9976, 'comp.os.ms-windows.misc', 'Re: How do I make GhostScript work?')),
#  'comp.sys.ibm.pc.hardware': ((6479, 'comp.sys.ibm.pc.hardware', 'ion: na'),
#   (2132, 'misc.forsale', 'Software and Hardware FOR SALE'),
#   (8023, 'misc.forsale', 'Newtek Video Toaster Link For Sale'),
#   (1077, 'misc.forsale', 'Baseball card FOR SALE'),
#   (9156, 'comp.sys.ibm.pc.hardware', 'Serial multiport card for sale.'),
#   (3022, 'misc.forsale', 'Lots of neat IBM clone stuff for sale'),
#   (8285, 'misc.forsale', 'CASIO B.O.S.S. For Sale'),
#   (1083, 'comp.os.ms-windows.misc', 'ATI Ultra Pro Confirmation'),
#   (5260, 'comp.sys.ibm.pc.hardware', 'Re: Winjet accelerator card')),
#  'comp.sys.mac.hardware': ((3555,
#    'comp.sys.mac.hardware',
#    "Re: Centris 610 Video Problem - I'm having it also!"),
#   (5298,
#    'comp.sys.mac.hardware',
#    "re: Centris 610 Video Problem - I'm having it also!"),
#   (7947, 'comp.sys.mac.hardware', 'Centris 610 Video Problem-HELP'),
#   (10656,
#    'comp.sys.mac.hardware',
#    "Re: Centris 610 Video Problem - I'm having it also!"),
#   (7410,
#    'comp.sys.mac.hardware',
#    "Re: Centris 610 Video Problem - I'm having it also!"),
#   (4616, 'comp.sys.mac.hardware', 'Re: Monitor turning off on its own'),
#   (9194, 'sci.electronics', 'Shrunken monitor window?'),
#   (6936,
#    'comp.graphics',
#    'pr@riverdale.enet.dec.com (869883 Thakkar Rahul Chandrakant)'),
#   (4894, 'comp.sys.mac.hardware', 'Re: 14" monitors')),
#  'comp.windows.x': ((6945,
#    'comp.windows.x',
#    'Re: Animation with XPutImage()?'),
#   (10097, 'comp.windows.x', 'Animation with XPutImage()?'),
#   (8856, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (8376, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (10487, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (10216, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (2056, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (5175, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (5198, 'comp.windows.x', 'Re: Animation with XPutImage()?')),
#  'misc.forsale': ((9931,
#    'misc.forsale',
#    'Onkyo 55w/ch integrated amp forsale:'),
#   (3309, 'misc.forsale', 'Onkyo Integra series Integrated amp for sale:'),
#   (9541, 'misc.forsale', 'Optonica tuner and Integrated amp forsale:'),
#   (10035, 'misc.forsale', 'Cheap airline ticket to L.A. wanted'),
#   (3478,
#    'talk.politics.misc',
#    'GUILTY .. or NOT GUILTY.........(comparitive fault law)'),
#   (1932, 'misc.forsale', 'WANTED:  FUTON'),
#   (10046, 'misc.forsale', "Oakleys' for sale; items wanted"),
#   (2368, 'rec.autos', 'Re: WARNING.....(please read)...'),
#   (3883, 'misc.forsale', 'Mother Board for sale')),
#  'rec.autos': ((6580, 'rec.autos', 'Re: New Alarm Proposal'),
#   (1375, 'rec.autos', 'Re: Most bang for $13k'),
#   (1287, 'rec.autos', 'Re: Most bang for $13k'),
#   (1123, 'rec.autos', 'Re: Too fast'),
#   (7993, 'rec.autos', 'Storing a car long term'),
#   (659,
#    'rec.autos',
#    "Re: New break pads & exhausts after 96K km (60K mi) on '90 Maxima?"),
#   (3819, 'rec.autos', 'Re: Ford Probe - Opinions? (centered around the GT)'),
#   (10559, 'rec.autos', 'Re: Dumbest automotive concepts of all tim'),
#   (771, 'rec.autos', 'Re: Integra GSR')),
#  'rec.motorcycles': ((4470, 'rec.motorcycles', 'Re: Observation re: helmets'),
#   (7269, 'rec.motorcycles', 'Re: hats update... patches too!'),
#   (5700, 'rec.motorcycles', 'Re: Round Two'),
#   (6457, 'rec.motorcycles', 'Re: insect impacts'),
#   (9038, 'rec.motorcycles', 'Re: Observation re: helmets'),
#   (1381, 'rec.motorcycles', 'Re: Live Free, but Quietly, or Die'),
#   (11180, 'rec.motorcycles', 'Re: A Miracle in California'),
#   (2952, 'rec.motorcycles', 'Re: Countersteering_FAQ please post'),
#   (470, 'misc.forsale', 'Typewriter w/computer interface')),
#  'rec.sport.baseball': ((10350,
#    'rec.sport.baseball',
#    "I've found the secret!"),
#   (4053, 'rec.sport.baseball', "Re: I've found the secret!"),
#   (540, 'rec.sport.baseball', "Re: I've found the secret!"),
#   (9952, 'rec.sport.baseball', 'Re: Jack Morris'),
#   (1857, 'rec.sport.baseball', 'Re: Jack Morris'),
#   (3441, 'rec.sport.baseball', 'Re: A surfeit of offense?'),
#   (586, 'rec.sport.baseball', 'Re: Pleasant Yankee Surprises'),
#   (733, 'rec.sport.baseball', 'Re: Jack Morris'),
#   (4547, 'rec.sport.baseball', 'Re: Jack Morris')),
#  'rec.sport.hockey': ((5713,
#    'rec.sport.hockey',
#    'My Predictions of a classic playoff year!'),
#   (5064, 'rec.sport.hockey', 'Re: My Predictions of a classic playoff year!'),
#   (3625, 'rec.sport.hockey', 'Yet more crazy predictions'),
#   (7195, 'rec.sport.hockey', 'Re: Playoff predictions'),
#   (9280, 'rec.sport.hockey', 'Re: Playoff predictions'),
#   (11050,
#    'rec.sport.hockey',
#    'What are you smoking? (wasRe: My Predictions of a classic playoff year!)'),
#   (7434, 'rec.sport.hockey', "Re: Vlad's Playoff Picks"),
#   (3313, 'rec.sport.hockey', 'My predictions'),
#   (11201, 'rec.sport.hockey', "Re: This Year's vs. Next Year's Playoffs")),
#  'sci.crypt': ((8983, 'sci.crypt', 'Clipper chip -- technical details'),
#   (4866, 'sci.crypt', 'More technical details'),
#   (2825, 'sci.crypt', 'Re: More technical details'),
#   (1735, 'sci.crypt', 'Some Questions (was: REVISED SUMMARY)'),
#   (6243, 'sci.crypt', 'Ideas on Clipper'),
#   (8151, 'sci.crypt', 'Re: Is there ANY security in the Clipper?'),
#   (8959, 'sci.crypt', 'Re: More technical details'),
#   (9365, 'sci.crypt', 'THE CLIPPER CHIP: A TECHNICAL SUMMARY'),
#   (11008,
#    'sci.crypt',
#    'Will FEDs troll for mutilated law enforcement blocks?')),
#  'sci.electronics': ((3758, 'sci.electronics', 'Re: Illusion'),
#   (7267, 'sci.electronics', 'Re: Illusion'),
#   (9774, 'rec.autos', "Re: Squeekin' Windows"),
#   (4669, 'sci.electronics', 'Re: digital voltmeter - how does it work?'),
#   (5999, 'talk.politics.guns', 'Re: Nazi memoribilia'),
#   (5197, 'sci.electronics', 'Re: Los Angeles Freeway traffic reports'),
#   (4279, 'rec.autos', 'Re: Dumbest automotive concepts of all time'),
#   (4446, 'sci.electronics', 'Re: Los Angeles Freeway traffic reports'),
#   (7061, 'rec.motorcycles', 'Guzzi 850-T tires, plus fairing question')),
#  'sci.med': ((1329, 'sci.med', 'Re: Migraines'),
#   (1588, 'sci.med', 'Re: Sinus vs. Migraine (was Re: Sinus Endoscopy)'),
#   (10251, 'sci.med', 'Re: Migraines and Estrogen'),
#   (7881, 'sci.med', 'Re: 3 AIDS Related Questions'),
#   (1300, 'sci.med', 'Re: migraine and exercise'),
#   (5788, 'sci.med', 'Re: Donating organs'),
#   (7213, 'sci.med', 'Re: tuberculosis'),
#   (10392, 'sci.med', 'Re: Fingernail "moons"'),
#   (6790, 'sci.med', 'Re: various migraine therapies')),
#  'sci.space': ((993, 'sci.space', 'Re: Boom!  Whoosh......'),
#   (6576, 'sci.space', 'Re: Boom!  Whoosh......'),
#   (9326, 'talk.politics.guns', 'Re: ACLU (was Re: Waco Shootout ...)'),
#   (8876, 'talk.politics.guns', 'Re: the usual'),
#   (10254, 'alt.atheism', 'Re: <<Pompous ass'),
#   (11172, 'sci.space', 'Re: New planet/Kuiper object found?'),
#   (1696,
#    'talk.politics.guns',
#    'Re: Another NYTimes Yellow-Sheet Editorial (4/4/93)'),
#   (2281, 'alt.atheism', 'Re: Amusing atheists and agnostics'),
#   (5193, 'comp.sys.mac.hardware', 'ImageWriter II at 50 Hz')),
#  'soc.religion.christian': ((5004,
#    'soc.religion.christian',
#    'Re: The arrogance of Christians'),
#   (11187, 'soc.religion.christian', 'Re: The arrogance of Christians'),
#   (6438, 'soc.religion.christian', 'Re: The arrogance of Christians'),
#   (8845,
#    'soc.religion.christian',
#    '[soc.religion.christian] Re: The arrogance of Christians'),
#   (9384, 'soc.religion.christian', 'Re: The arrogance of Christians'),
#   (9904, 'soc.religion.christian', '"Accepting Jeesus in your heart..."'),
#   (718, 'soc.religion.christian', 'Re: The arrogance of Christians'),
#   (1749, 'soc.religion.christian', 'Re: The arrogance of Christians'),
#   (614, 'soc.religion.christian', 'Re: The arrogance of Christians')),
#  'talk.politics.guns': ((8281, 'talk.politics.guns', 'S4@psuvm.psu.edu>'),
#   (1912,
#    'talk.politics.guns',
#    'Re: Clinton wants National ID card, aka USSR-style "Internal Passport"'),
#   (2085,
#    'talk.politics.guns',
#    'Re: Clinton wants National ID card, aka USSR-style "Internal Passport"'),
#   (4446, 'sci.electronics', 'Re: Los Angeles Freeway traffic reports'),
#   (4000, 'sci.electronics', 'Re: Radio Electronics Free information card'),
#   (10941,
#    'talk.politics.guns',
#    'Re: Clinton wants National ID card, aka USSR-style "Internal Passport"'),
#   (5526, 'talk.politics.misc', 'Re: Defense against the detractors...'),
#   (8507,
#    'comp.sys.ibm.pc.hardware',
#    'Re: warranty extension by credit company: applies to the phurchase of computer?'),
#   (6792, 'talk.politics.guns', 'Re: What to do if you shoot somebody')),
#  'talk.politics.mideast': ((10377,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (7440,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (1334,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (7012,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (894,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (5483,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (3032,
#    'talk.politics.mideast',
#    'Re: If You Feed Armenians Dirt -- You Will Bite Dust!'),
#   (10676, 'talk.politics.mideast', 'Ozal Died!'),
#   (5332,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES')),
#  'talk.politics.misc': ((6107, 'talk.politics.misc', 'PBC@CUNYVM.BITNET>'),
#   (3838, 'soc.religion.christian', 'Re: SSPX schism ?'),
#   (7510, 'talk.politics.misc', 'NLNS: Fascism with a Friendly Face'),
#   (9697, 'talk.politics.misc', 'Re: NLNS: Fascism with a Friendly Face'),
#   (7729,
#    'talk.religion.misc',
#    'x@charlie.usd.edu (Rich Fox, Univ of South Dakota)'),
#   (8218, 'talk.politics.misc', 'Re: Will Italy be the Next Domino to Fall?'),
#   (8197,
#    'talk.religion.misc',
#    'Re: NEW BIBLICAL CONTRADICTIONS [Fallaciously] ANSWERED (Judas)'),
#   (6061,
#    'talk.religion.misc',
#    "Re: [lds] kermit's reply [was: Re: Tony Rose was : FREE BOOK OF MORMON"),
#   (7242, 'talk.religion.misc', 'SCCK@BYUVM.BITNET>')),
#  'talk.religion.misc': ((7142,
#    'talk.religion.misc',
#    'Re: A Message for you Mr. President: How do you know what happened?'),
#   (1737,
#    'talk.religion.misc',
#    'Re: A Message for you Mr. President: How do you know what happened?'),
#   (3984, 'rec.autos', 'Re: WARNING.....(please read)...'),
#   (3196, 'talk.politics.guns', 'Raid justification was: Blast them next time'),
#   (9612,
#    'talk.religion.misc',
#    'Re: A Message for you Mr. President: How do you know what happened?'),
#   (9851,
#    'talk.politics.guns',
#    'Re: BATF/FBI Murders Almost Everyone in Waco Today! 4/19'),
#   (6791,
#    'talk.politics.guns',
#    'Re: BATF/FBI Murders Almost Everyone in Waco Today! 4/19'),
#   (2425,
#    'talk.religion.misc',
#    'Re: A Message for you Mr. President: How do you know what happened?'),
#   (3865, 'comp.os.ms-windows.misc', 'Re: multiple desktops'))}

# %% [markdown]
# ### 2.3. Question 3

# %% [markdown]
# Recall from the docstring of the `NearestNeighborsFinder` class (§1.4) that **the reduction we want here, for all the documents in the dataset, is just its** `.PQ_labels` **attribute.** As far as our sample is concerned, we just need to extract the relevant 20 rows from it:

# %%
for i in dataset.sample:
  print("Its:", dataset.its(i), ", labels:", nnf.PQ_labels[i, :])
# Out:
# Its: (8541, 'alt.atheism', 'Re: Genocide is Caused by Theism : Evidence?') , labels: [242 208 238 114  36  45 180  55 224 176  26 115  16  13  52  53]
# Its: (6717, 'comp.graphics', 'Re: Rumours about 3DO ???') , labels: [142 222 225 169 214  77  92  91 243 165  75 215 107   7  19   2]
# Its: (2557, 'comp.os.ms-windows.misc', 'Re: Utility for updating Win.ini and system.ini') , labels: [ 13  85 164 145 107  39 149  49  88 223  85 146 121   6 204 218]
# Its: (6479, 'comp.sys.ibm.pc.hardware', 'ion: na') , labels: [200  36 156 248  15  48 205 187 247 187 177 247 227 182   9 227]
# Its: (3555, 'comp.sys.mac.hardware', "Re: Centris 610 Video Problem - I'm having it also!") , labels: [237  59 253  24 209  35 125 137  21 153 142  77  41 238 208  38]
# Its: (6945, 'comp.windows.x', 'Re: Animation with XPutImage()?') , labels: [181 246 138 251 226 243 215 181 175  90  32  93  13  42 200 126]
# Its: (9931, 'misc.forsale', 'Onkyo 55w/ch integrated amp forsale:') , labels: [123 158 251 171  31  14 229 129  90  63 225 183 146 220 131 235]
# Its: (6580, 'rec.autos', 'Re: New Alarm Proposal') , labels: [ 95 184 160 179  25 191 122  92 178 198 152 164 183  59 143  29]
# Its: (4470, 'rec.motorcycles', 'Re: Observation re: helmets') , labels: [116 174 237  85  64 188  10  79  48 213 222  29  66 150  16  41]
# Its: (10350, 'rec.sport.baseball', "I've found the secret!") , labels: [ 56  99 215  71   9 247 146 142 229 114  78 105   3  70  48  31]
# Its: (5713, 'rec.sport.hockey', 'My Predictions of a classic playoff year!') , labels: [207 120 250  82 136  46 167 128 225  85 221  91 163  27 171 154]
# Its: (8983, 'sci.crypt', 'Clipper chip -- technical details') , labels: [ 26 255  96  31  74 116 174  32 148 160 144  87  45  20 140 179]
# Its: (3758, 'sci.electronics', 'Re: Illusion') , labels: [186  76 160 121   5  58  73 110  64  36 120  64 168 134 192  47]
# Its: (1329, 'sci.med', 'Re: Migraines') , labels: [124  77  72  97  88 110   4 229 109 207 239 162 111 173  70  48]
# Its: (993, 'sci.space', 'Re: Boom!  Whoosh......') , labels: [133  25 255  50   2  77 206 194 178  55 167  21   0 210 155  54]
# Its: (5004, 'soc.religion.christian', 'Re: The arrogance of Christians') , labels: [217   1  69  12 175  37 222 157 211  56 187  60 252 168  19  71]
# Its: (8281, 'talk.politics.guns', 'S4@psuvm.psu.edu>') , labels: [ 78  56 242 151 213 152 198 125 223 235  44  40 125  33 229 125]
# Its: (10377, 'talk.politics.mideast', 'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES') , labels: [  9  73 173 250 134 117 218 112  11 152 143 217 116  50 125 216]
# Its: (6107, 'talk.politics.misc', 'PBC@CUNYVM.BITNET>') , labels: [174  30  83 122  23  10 151 232 233   6 101  46  29 182 100  22]
# Its: (7142, 'talk.religion.misc', 'Re: A Message for you Mr. President: How do you know what happened?') , labels: [126 195 215 194  98  13   8 145  96 174  96  19 171  96 139  65]

# %% [markdown]
# ### 2.4. Question 4

# %% [markdown]
# We just need to call `nearest_neighbors()` (see §1.5) with the parameter `distance='PQ'` (our sample is still the same):

# %%
nearest_neighbors(n_neighbors=8, dataset=dataset, nnf=nnf, distance='PQ')
# Out:
# {'alt.atheism': ((8541,
#    'alt.atheism',
#    'Re: Genocide is Caused by Theism : Evidence?'),
#   (8071, 'alt.atheism', 'Re: islamic genocide'),
#   (6651, 'alt.atheism', 'Re: The Inimitable Rushdie'),
#   (3289, 'talk.religion.misc', 'Re: Albert Sabin'),
#   (1785, 'sci.space', 'Re: Sunrise/ sunset times'),
#   (252, 'alt.atheism', 'Re: Who Says the Apostles Were Tortured?'),
#   (1534, 'alt.atheism', 'Re: Wholly Babble (Was Re: free moral agency)'),
#   (3906, 'alt.atheism', "Re: A visit from the Jehovah's Witnesses"),
#   (1236, 'misc.forsale', 'NEW AIRCRAFT TU-154M')),
#  'comp.graphics': ((6717, 'comp.graphics', 'Re: Rumours about 3DO ???'),
#   (6142, 'comp.graphics', 'Re: Rumours about 3DO ???'),
#   (3306, 'sci.med', 'Re: Lasers for dermatologists'),
#   (4501, 'sci.med', 'Re: Blood Glucose test strips'),
#   (1038, 'sci.electronics', 'Homebuilt PAL (EPLD) programer?'),
#   (5465,
#    'comp.os.ms-windows.misc',
#    'DOS6 - doublespace + stacker 3.0, is it okay?'),
#   (9647, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (7268, 'sci.electronics', 'Re: 6551A and 6551 compatibility'),
#   (2385, 'misc.forsale', 'Victoria, B.C. Hotel Room $40/2 nights')),
#  'comp.os.ms-windows.misc': ((2557,
#    'comp.os.ms-windows.misc',
#    'Re: Utility for updating Win.ini and system.ini'),
#   (2452,
#    'comp.os.ms-windows.misc',
#    'Re: Utility for updating Win.ini and system.ini'),
#   (255,
#    'comp.os.ms-windows.misc',
#    'Re: Utility for updating Win.ini and system.ini'),
#   (675,
#    'comp.os.ms-windows.misc',
#    'Utility for updating Win.ini and system.ini'),
#   (58,
#    'comp.os.ms-windows.misc',
#    'Re: Utility for updating Win.ini and system.ini'),
#   (1057, 'comp.os.ms-windows.misc', 'phen.Gibson@sonoma.edu <Stephen Gibson>'),
#   (2989, 'comp.os.ms-windows.misc', 'How do I make GhostScript work?'),
#   (4677, 'comp.os.ms-windows.misc', 'How do I make GhostScript work?'),
#   (3771, 'comp.os.ms-windows.misc', 'Re: Windows Help')),
#  'comp.sys.ibm.pc.hardware': ((6479, 'comp.sys.ibm.pc.hardware', 'ion: na'),
#   (108, 'comp.graphics', 'Re: Genoa Blitz 24 hits 1600x1200x256 NI !'),
#   (4644, 'misc.forsale', 'Borland Software for sale - CHEAP!'),
#   (8830, 'sci.electronics', 'Magstrip Card Reader Info'),
#   (3828,
#    'comp.os.ms-windows.misc',
#    'ni@shannon.tisl.ukans.edu (Srini Seetharam)'),
#   (2090, 'misc.forsale', 'Moving Sale'),
#   (5731, 'misc.forsale', "16' HobieCat Special"),
#   (7855, 'misc.forsale', '3M DC6150s for sale'),
#   (1077, 'misc.forsale', 'Baseball card FOR SALE')),
#  'comp.sys.mac.hardware': ((3555,
#    'comp.sys.mac.hardware',
#    "Re: Centris 610 Video Problem - I'm having it also!"),
#   (5298,
#    'comp.sys.mac.hardware',
#    "re: Centris 610 Video Problem - I'm having it also!"),
#   (10656,
#    'comp.sys.mac.hardware',
#    "Re: Centris 610 Video Problem - I'm having it also!"),
#   (7947, 'comp.sys.mac.hardware', 'Centris 610 Video Problem-HELP'),
#   (7410,
#    'comp.sys.mac.hardware',
#    "Re: Centris 610 Video Problem - I'm having it also!"),
#   (4616, 'comp.sys.mac.hardware', 'Re: Monitor turning off on its own'),
#   (290, 'comp.windows.x', 'Q: Colormaps with dialog shells'),
#   (5947, 'sci.electronics', 'Re: Getting rid of screen wiggles?'),
#   (5990,
#    'comp.windows.x',
#    'Is a 2 headed Sun 3/60 possible (cgfour0/bwtwo0)')),
#  'comp.windows.x': ((6945,
#    'comp.windows.x',
#    'Re: Animation with XPutImage()?'),
#   (10097, 'comp.windows.x', 'Animation with XPutImage()?'),
#   (10487, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (8376, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (5175, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (2056, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (10216, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (8856, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (9043, 'comp.windows.x', '**** CURSOR SIZE PROBLEMS ****')),
#  'misc.forsale': ((3309,
#    'misc.forsale',
#    'Onkyo Integra series Integrated amp for sale:'),
#   (9931, 'misc.forsale', 'Onkyo 55w/ch integrated amp forsale:'),
#   (1932, 'misc.forsale', 'WANTED:  FUTON'),
#   (10035, 'misc.forsale', 'Cheap airline ticket to L.A. wanted'),
#   (10150, 'misc.forsale', 'Wanted: AIRCONDITIONER'),
#   (6767, 'misc.forsale', 'Super Scope6 for sale (SNES)'),
#   (622,
#    'rec.sport.hockey',
#    'LIST OF TEE TIMES AT METROPOLITAN TORONTO GOLF COURSES FOR MONDAY'),
#   (3478,
#    'talk.politics.misc',
#    'GUILTY .. or NOT GUILTY.........(comparitive fault law)'),
#   (8989, 'sci.space', 'Re: Sunrise/ sunset times')),
#  'rec.autos': ((6580, 'rec.autos', 'Re: New Alarm Proposal'),
#   (7993, 'rec.autos', 'Storing a car long term'),
#   (9084,
#    'rec.autos',
#    "My two cars - Chevy Nova CL ('87) and Dodge 600 SE ('87)"),
#   (29, 'rec.autos', 'Re: Is car saftey important?'),
#   (10513, 'rec.autos', 'Re: Integra GSR (really about other cars)'),
#   (9018, 'rec.autos', 'Waxing a new car'),
#   (10715, 'rec.autos', 'Re: Where can I get a New York taxi?'),
#   (2656, 'rec.autos', 'Re: saturn -- puzzled by its pricing'),
#   (2086, 'rec.autos', 'Toyota Land Cruiser worth it?')),
#  'rec.motorcycles': ((4470, 'rec.motorcycles', 'Re: Observation re: helmets'),
#   (7269, 'rec.motorcycles', 'Re: hats update... patches too!'),
#   (5700, 'rec.motorcycles', 'Re: Round Two'),
#   (9038, 'rec.motorcycles', 'Re: Observation re: helmets'),
#   (6457, 'rec.motorcycles', 'Re: insect impacts'),
#   (1381, 'rec.motorcycles', 'Re: Live Free, but Quietly, or Die'),
#   (470, 'misc.forsale', 'Typewriter w/computer interface'),
#   (11180, 'rec.motorcycles', 'Re: A Miracle in California'),
#   (2952, 'rec.motorcycles', 'Re: Countersteering_FAQ please post')),
#  'rec.sport.baseball': ((10350,
#    'rec.sport.baseball',
#    "I've found the secret!"),
#   (4053, 'rec.sport.baseball', "Re: I've found the secret!"),
#   (540, 'rec.sport.baseball', "Re: I've found the secret!"),
#   (6358, 'rec.sport.baseball', 'G. Williams sent down; Yanks win AL East'),
#   (7953,
#    'rec.sport.baseball',
#    'Re: Bosox win again! (the team record is 9-3)'),
#   (1570, 'rec.sport.baseball', "Re: And America's Team is....But Why?"),
#   (5710, 'rec.sport.baseball', 'Re: Royals'),
#   (5149,
#    'rec.sport.baseball',
#    'Re: Expanded NL Strike Zone? (Was Re: A surfeit of offense?)'),
#   (7950, 'rec.sport.baseball', 'Re: Old Predictions to laugh at...')),
#  'rec.sport.hockey': ((5713,
#    'rec.sport.hockey',
#    'My Predictions of a classic playoff year!'),
#   (5064, 'rec.sport.hockey', 'Re: My Predictions of a classic playoff year!'),
#   (3625, 'rec.sport.hockey', 'Yet more crazy predictions'),
#   (7195, 'rec.sport.hockey', 'Re: Playoff predictions'),
#   (4073, 'rec.sport.hockey', 'Re: Playoff predictions'),
#   (9280, 'rec.sport.hockey', 'Re: Playoff predictions'),
#   (11050,
#    'rec.sport.hockey',
#    'What are you smoking? (wasRe: My Predictions of a classic playoff year!)'),
#   (3313, 'rec.sport.hockey', 'My predictions'),
#   (11201, 'rec.sport.hockey', "Re: This Year's vs. Next Year's Playoffs")),
#  'sci.crypt': ((8983, 'sci.crypt', 'Clipper chip -- technical details'),
#   (2825, 'sci.crypt', 'Re: More technical details'),
#   (4866, 'sci.crypt', 'More technical details'),
#   (8959, 'sci.crypt', 'Re: More technical details'),
#   (2203,
#    'sci.crypt',
#    'Re: Off the shelf cheap DES keyseach machine (Was: Re: Corporate acceptance of the wiretap chip)'),
#   (2640, 'sci.crypt', 'Clipper -- some new thoughts'),
#   (8181, 'sci.crypt', 'Re: More technical details'),
#   (1735, 'sci.crypt', 'Some Questions (was: REVISED SUMMARY)'),
#   (6243, 'sci.crypt', 'Ideas on Clipper')),
#  'sci.electronics': ((3758, 'sci.electronics', 'Re: Illusion'),
#   (6482, 'talk.religion.misc', 'Re: BIBLICAL CONTRADICTIONS and Archer'),
#   (7267, 'sci.electronics', 'Re: Illusion'),
#   (7293, 'rec.motorcycles', 'GS1100E (was Re: buying advice needed)'),
#   (9774, 'rec.autos', "Re: Squeekin' Windows"),
#   (7233, 'rec.motorcycles', 'Re: Cobra Locks'),
#   (5646, 'sci.med', 'Exercise and Migraine'),
#   (8398, 'sci.electronics', '2 level brightness Xmas light set (for Easter?'),
#   (4675, 'sci.med', 'Re: Lung disorders and clubbing of fingers')),
#  'sci.med': ((1329, 'sci.med', 'Re: Migraines'),
#   (5788, 'sci.med', 'Re: Donating organs'),
#   (1300, 'sci.med', 'Re: migraine and exercise'),
#   (3348,
#    'sci.med',
#    'Re: NIH offers "Exploratory Grants For Alternative Medicine"'),
#   (3185, 'sci.med', 'Re: My New Diet --> IT WORKS GREAT !!!!'),
#   (10251, 'sci.med', 'Re: Migraines and Estrogen'),
#   (1588, 'sci.med', 'Re: Sinus vs. Migraine (was Re: Sinus Endoscopy)'),
#   (10392, 'sci.med', 'Re: Fingernail "moons"'),
#   (3866, 'sci.med', 'Re: health care reform')),
#  'sci.space': ((993, 'sci.space', 'Re: Boom!  Whoosh......'),
#   (11135, 'sci.electronics', 'An external timer'),
#   (9439, 'sci.med', 'Re: Foreskin Troubles'),
#   (3161, 'sci.med', "Re: Can't wear contacts after RK/PRK?"),
#   (9647, 'comp.windows.x', 'Re: Animation with XPutImage()?'),
#   (11188, 'talk.religion.misc', 'Bhagavad-Gita 2.44'),
#   (9049, 'rec.sport.hockey', 'Re: WHERE ARE THE DOUBTERS NOW?  HMM?'),
#   (1654, 'rec.autos', 'Re: $6700 for hail damage - a record?'),
#   (8189,
#    'talk.religion.misc',
#    'Re: Hitler - pagan or Christian? (Was: Martin Luther...)')),
#  'soc.religion.christian': ((5004,
#    'soc.religion.christian',
#    'Re: The arrogance of Christians'),
#   (9384, 'soc.religion.christian', 'Re: The arrogance of Christians'),
#   (2629, 'soc.religion.christian', 'Re: The arrogance of Christians'),
#   (8845,
#    'soc.religion.christian',
#    '[soc.religion.christian] Re: The arrogance of Christians'),
#   (2444, 'soc.religion.christian', 'Re: Pantheism & Environmentalism'),
#   (5765,
#    'soc.religion.christian',
#    'Re: Losing your temper is not a Christian trait'),
#   (468, 'soc.religion.christian', 'Re: The arrogance of Christians'),
#   (2984,
#    'soc.religion.christian',
#    'Re: Losing your temper is not a Christian trait'),
#   (1266, 'talk.religion.misc', 'Re: JUDAS, CRUCIFIXION, TYRE, Etc...')),
#  'talk.politics.guns': ((8281, 'talk.politics.guns', 'S4@psuvm.psu.edu>'),
#   (1912,
#    'talk.politics.guns',
#    'Re: Clinton wants National ID card, aka USSR-style "Internal Passport"'),
#   (2085,
#    'talk.politics.guns',
#    'Re: Clinton wants National ID card, aka USSR-style "Internal Passport"'),
#   (4446, 'sci.electronics', 'Re: Los Angeles Freeway traffic reports'),
#   (10612, 'sci.electronics', 'Re: making copy of a Video tape'),
#   (8507,
#    'comp.sys.ibm.pc.hardware',
#    'Re: warranty extension by credit company: applies to the phurchase of computer?'),
#   (9770, 'talk.religion.misc', 'Walter?'),
#   (989, 'rec.motorcycles', 'Re: MAIL ORDER'),
#   (3535, 'sci.med', 'Re: Should I be angry at this doctor?')),
#  'talk.politics.mideast': ((10377,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (7440,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (1334,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (894,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (7012,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (5483,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (4195,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (5332,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES'),
#   (1087,
#    'talk.politics.mideast',
#    'Re: ARMENIA SAYS IT COULD SHOOT DOWN TURKISH PLANES (Henrik)')),
#  'talk.politics.misc': ((6107, 'talk.politics.misc', 'PBC@CUNYVM.BITNET>'),
#   (8667, 'talk.politics.misc', 'Recent News'),
#   (7750, 'talk.religion.misc', 'Bhagavad-Gita 2.45'),
#   (3891,
#    'talk.politics.misc',
#    'Re: Pro-abortion feminist leader endorses trashing of free speech rights'),
#   (6613,
#    'talk.politics.mideast',
#    'Re: The U.S. Holocaust Memorial Museum: A Costly...'),
#   (6250,
#    'talk.religion.misc',
#    'Re: OTO, the Ancient Order of Oriental Templars'),
#   (9305, 'talk.politics.mideast', 'PR Campaign Against Iran (PBS Frontline)'),
#   (563, 'talk.politics.mideast', 'Re: THE HAMAS WAY of DEATH'),
#   (1885, 'sci.med', 'Re: what are the problems with nutrasweet (aspartame)')),
#  'talk.religion.misc': ((7142,
#    'talk.religion.misc',
#    'Re: A Message for you Mr. President: How do you know what happened?'),
#   (2249, 'talk.politics.guns', 'Re: Some more about gun control...'),
#   (827, 'rec.autos', 'Re: WARNING.....(please read)...'),
#   (2314, 'comp.windows.x', 'WANTED: X & security posting'),
#   (7204, 'sci.crypt', 'Re: Cryptology in the world'),
#   (4761, 'sci.med', 'Re: OCD'),
#   (8059, 'talk.religion.misc', 'Re: RFD: misc.taoism'),
#   (6207, 'rec.motorcycles', 'Re: Twit Bicyclists (was RE: Oh JOY!)'),
#   (10971, 'sci.med', 'Re: Hernia'))}
